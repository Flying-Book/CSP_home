# %% [markdown]
# # Night at The Museum Reflection
# ## Our Project Feedback (Demo)
# ### Glows:
# People liked our interactive visual elements because it made the UI more interactive and inuitive. Techy people also appreciated the JWT Token roles and CRUD functions through the special admin rights, registartion page, and sign up.
# - Piecharts (healthy meal tracker)
# - Stress Progress Bar (Stress)
# - Graphs (Sleep and Exercise)
# - Profile Creation (students appreciated the profile coustomization and avalible avatars, techy people liked the tech based names and ascii style)
# - Registration Page
#
# ### Grows:
# Professional Feedback:
# - Deploy website and show schema change from cockpit
# - Add option to upload profile picture to profile creation and display
#
# Peer Feedback:
# - Add a drinks API or .csv file to calculate the amount of hydration and sugar in each drink and connect it to the coins feature
# - Try a food API as well
#
# Extra Feedback:
# - Make iframes easier to manage
# - Add leaderboard based on coins to promote interuser competition + rewards based on position
# - Make our frontend look more asethtic (more characters + page specific backgrounds)
#
# ### What I will change:
# - I will have the piechart for the USDA on full display because the piechart is constant (only the user one changes so it should be there when link is opened).
# - I will have more instructions on webpage on how ot use features to explain to the user.
# - I will also try to find an alterntaive to iframes because they can be hard to use and manade.
# - Add a drinks api (maybe with [Coffee API](https://sampleapis.com/api-list/coffee))
#
# ## N@TM Blog
# ### CSSE Mario Game
# CSSE had a super Mario game which the entire class worked on. It allowed for multiplayer use and had a leaderboard. The game itself had pretty good graphics for characters and the background.
# Takeaways: Collaboration, implementing somesort of leaderboard to inpsire competition
# Suggestions: Maybe store data in sql database in the backend with JWT instead of using local storage
# ![Alt Text]({{site.baseurl}}/images/IMG_3392.jpg)
# ### Health Tracker
# It was nice to see a similar project and the variety within our features. I liked that they had more external APIs than us. They had many of the same features which was expected as we had a similar topic.
# Suggestions: Replace .csv files with .api links and don't display .csv on frontend
# Takeways: What can we do to differentiate our Fitness Tracker from the competition?
# ![Alt Text]({{site.baseurl}}/images/IMG_3388.jpg)
#
# ### Oppurtunity Connect
# This was a website that allowed people to register for different volunteering events and for admins to create volunteering events. It simplified registration by event sorting and automatic updating slots.
# Suggestions: Add more color to the front-end
# Takeaways: Make repo relavent to the audience, presentation skills
# ![Alt Text]({{site.baseurl}}/images/IMG_3390.jpg)
# ### Other non-coding projects I saw
# - I went next door to look at pictures in the photography room. My favorite picture was the one with the color pencils and the eye. I like the use of photoshop and the pop of color from the pencils.
# ![Alt Text]({{site.baseurl}}/images/IMG_1056.jpg)
# - I went to Drawing and Painting + AP Studio Art and looked at the different pictures drawn by students. Here are some of my favorites.
# ![Alt Text]({{site.baseurl}}/images/IMG_3396.jpg)
# ![Alt Text]({{site.baseurl}}/images/IMG_3394.jpg)
# ![Alt Text]({{site.baseurl}}/images/IMG_3395.jpg)
# - I went to Ceramics and looked at the different pieces. My favorite were the garden gnomes.
# ![Alt Text]({{site.baseurl}}/images/IMG_3393.jpg)
